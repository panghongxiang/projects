# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 3: Developing a classification model for Twitter topics (Formula 1 vs MotoGP)

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Collection](#Data-Collection)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)

# %% [markdown]
# ## Background

# %% [markdown]
# Since the release of the popular Netflix series "Drive to Survive" on 8th March 2019, Formula 1’s popularity has risen rapidly on Twitter, with the number of followers on their official account increasing from 3.5million in 2018 to 9.1million in 2023. Given the influx of interest in the topic of Formula 1, there is a need for a classifier to differentiate tweets about Formula 1 from other auto racing related tweets such as MotoGP, Nascar, etc, such that Twitter is able to recommend the relevant tweets to users' news feeds.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Twitter needs a classification model that maximizes the recommendation of Formula 1 related tweets to users who have indicated interest in the topic, while minimizing the recommendation of other auto racing related tweets.
#
# This project aims to build a classifier that is able to differentiate Formula 1 related tweets from MotoGP related tweets.

# %% [markdown]
# ## Data Collection

# %% [markdown]
# For this project, we will be scraping tweets from the official twitter accounts of Formula 1 (@F1) and MotoGP (@MotoGP) for the period of 1st Jan 2022 to 28th Feb 2023. The official racing seasons for both runs from March to November, and during the off season we expect that the tweets would be of a different nature compared to during the racing season. Our dataset would contain tweets from both racing season and off-season, so that our model will be able to account for seasonal differences.

# %%
# Import libraries
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
# Scraping Tweets from @F1
f1_tweets = []

f1_scraper = sntwitter.TwitterSearchScraper('"from:F1" since:2022-01-01 until:2023-02-28')
for i, tweet in enumerate(f1_scraper.get_items()):
    data = [
        tweet.date,
        tweet.rawContent,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
    ]
    f1_tweets.append(data)

# %%
# Checking number of F1 tweets collected
len(f1_tweets)
# Out:
# 8173

# %%
# Compiling the F1 data into a dataframe
f1_df = pd.DataFrame(f1_tweets, columns = ['date','content','username','like_count','retweet_count'])
f1_df
# Out:
#                           date  \
# 0    2023-02-27 20:00:00+00:00
# 1    2023-02-27 19:00:02+00:00
# 2    2023-02-27 18:02:00+00:00
# 3    2023-02-27 17:55:00+00:00
# 4    2023-02-27 17:37:05+00:00
# ...                        ...
# 8168 2022-01-01 17:17:15+00:00
# 8169 2022-01-01 14:54:00+00:00
# 8170 2022-01-01 11:30:00+00:00
# 8171 2022-01-01 08:48:00+00:00
# 8172 2022-01-01 00:00:02+00:00
#
#                                                 content username  like_count  \
# 0     Tensions were running high between the Team Pr...       F1       22495
# 1     Striking a pose, ft. a glorious mullet too ✨\n...       F1        3552
# 2     💰🆕 FANTASY PRICE REVEAL 🆕💰\n\nCreate your ulti...       F1        1526
# 3     It's almost time for F1 Fantasy to restart! 🤩\...       F1        1215
# 4     We couldn't not put these two together! 🥰\n\n@...       F1        8126
# ...                                                 ...      ...         ...
# 8168  New car, new circuit, new driver line-ups...\n...       F1        6087
# 8169  Give us one bold prediction for the 2022 seaso...       F1       12284
# 8170  Time to get these dates down so you don't miss...       F1       51321
# 8171  New year. New car. New era.\n\n#F1 #HappyNewYe...       F1       65253
# 8172  Wishing a very Happy New Year to all F1 fans! ...       F1       16870
#
#       retweet_count
# 0              1637
# 1               291
# 2               146
# 3               210
# 4               785
# ...             ...
# 8168            342
# 8169            308
# 8170           7542
# 8171           4489
# 8172           1604
#
# [8173 rows x 5 columns]

# %%
# Scraping Tweets from @MotoGP
motogp_tweets = []

motogp_scraper = sntwitter.TwitterSearchScraper('"from:MotoGP" since:2022-01-01 until:2023-02-28')
for i, tweet in enumerate(motogp_scraper.get_items()):
    data = [
        tweet.date,
        tweet.rawContent,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
    ]
    motogp_tweets.append(data)

# %%
# Checking number of MotoGP tweets collected
len(motogp_tweets)
# Out:
# 11677

# %%
# Compiling the MotoGP data into a dataframe
motogp_df = pd.DataFrame(motogp_tweets, columns = ['date','content','username','like_count','retweet_count'])
motogp_df
# Out:
#                            date  \
# 0     2023-02-27 12:40:00+00:00
# 1     2023-02-27 12:30:59+00:00
# 2     2023-02-27 12:28:33+00:00
# 3     2023-02-27 11:15:24+00:00
# 4     2023-02-26 09:01:15+00:00
# ...                         ...
# 11672 2022-01-01 21:30:39+00:00
# 11673 2022-01-01 19:01:13+00:00
# 11674 2022-01-01 17:02:17+00:00
# 11675 2022-01-01 15:01:06+00:00
# 11676 2022-01-01 12:06:22+00:00
#
#                                                  content username  like_count  \
# 0      @KTM_Racing @GresiniRacing @pramacracing Six d...   MotoGP         115
# 1      The 2023 grid is looking great so far! 🔥 https...   MotoGP         348
# 2      We've had some cool team presentations so far!...   MotoGP        1384
# 3      Five team launches, the #PortimaoTest and so m...   MotoGP         347
# 4      About last Sunday 😎 \n\nWe just cannot get eno...   MotoGP        1262
# ...                                                  ...      ...         ...
# 11672  @jazzycat62 @ValeYellow46 https://t.co/Up0SRc0...   MotoGP           7
# 11673  The man that defined over 2 decades of #MotoGP...   MotoGP        3284
# 11674  Chapter 9 - Where Heroes Are Made 🦸‍♂️\n\nOne ...   MotoGP         438
# 11675  "Maybe one day" 👀\n\nThere are many that think...   MotoGP         433
# 11676       Hello 2️⃣0️⃣2️⃣2️⃣ 🏁 https://t.co/9MFk9GHzmC   MotoGP        5502
#
#        retweet_count
# 0                 10
# 1                 35
# 2                134
# 3                 39
# 4                140
# ...              ...
# 11672              2
# 11673            570
# 11674             52
# 11675             25
# 11676           1445
#
# [11677 rows x 5 columns]

# %%
# Combine F1 and MotoGP datasets
df = f1_df.append(motogp_df)
df
# Out:
# /var/folders/3n/fkv2x4vs6_jc1rvhs53fssxr0000gn/T/ipykernel_2056/332668702.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = f1_df.append(motogp_df)
#                            date  \
# 0     2023-02-27 20:00:00+00:00
# 1     2023-02-27 19:00:02+00:00
# 2     2023-02-27 18:02:00+00:00
# 3     2023-02-27 17:55:00+00:00
# 4     2023-02-27 17:37:05+00:00
# ...                         ...
# 11672 2022-01-01 21:30:39+00:00
# 11673 2022-01-01 19:01:13+00:00
# 11674 2022-01-01 17:02:17+00:00
# 11675 2022-01-01 15:01:06+00:00
# 11676 2022-01-01 12:06:22+00:00
#
#                                                  content username  like_count  \
# 0      Tensions were running high between the Team Pr...       F1       22495
# 1      Striking a pose, ft. a glorious mullet too ✨\n...       F1        3552
# 2      💰🆕 FANTASY PRICE REVEAL 🆕💰\n\nCreate your ulti...       F1        1526
# 3      It's almost time for F1 Fantasy to restart! 🤩\...       F1        1215
# 4      We couldn't not put these two together! 🥰\n\n@...       F1        8126
# ...                                                  ...      ...         ...
# 11672  @jazzycat62 @ValeYellow46 https://t.co/Up0SRc0...   MotoGP           7
# 11673  The man that defined over 2 decades of #MotoGP...   MotoGP        3284
# 11674  Chapter 9 - Where Heroes Are Made 🦸‍♂️\n\nOne ...   MotoGP         438
# 11675  "Maybe one day" 👀\n\nThere are many that think...   MotoGP         433
# 11676       Hello 2️⃣0️⃣2️⃣2️⃣ 🏁 https://t.co/9MFk9GHzmC   MotoGP        5502
#
#        retweet_count
# 0               1637
# 1                291
# 2                146
# 3                210
# 4                785
# ...              ...
# 11672              2
# 11673            570
# 11674             52
# 11675             25
# 11676           1445
#
# [19850 rows x 5 columns]

# %%
# Export combined dataset into csv
df.to_csv("../data/train_data.csv", index = False)

# %% [markdown]
# # Info on data collected
# Number of F1 tweets collected: 8,173
# Number of MotoGP tweets collected: 11,677
